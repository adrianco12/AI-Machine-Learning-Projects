# %% [markdown]
# # Data Preprocessing and Visualization
# This starter code lays the groundwork for the final end-to-end machine learning project. It focuses on essential steps of data preprocessing—including cleaning, handling missing values, and preparing features—and data visualization to explore patterns, trends, and distributions. The purpose is to establish a strong foundation before moving on to model building and evaluation.

# %%
# Step 0: Import libraries
from sklearn.datasets import fetch_california_housing
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Step 1: Load the dataset
housing = fetch_california_housing()
housing_df = pd.DataFrame(housing.data, columns=housing.feature_names) # create a Pandas Dataframe, a two dimensional data structure similar to a table.
housing_df.head() # # This returns the first 5 rows in our data frame.
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# Step 2: Simulate missing values (practice preprocessing)
# TODO: Make some values in one column missing

housing_df.loc[0:4, 'HouseAge'] = None # Using .loc to modify rows/columns by their name, not index. In this case, I am removing HouseAge from rows 0-4.
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252       NaN  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014       NaN  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574       NaN  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431       NaN  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462       NaN  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# Step 3: Fill missing values

housing_df['HouseAge'] = housing_df['HouseAge'].fillna(housing_df['HouseAge'].median()) # selecting the HouseAge column and setting it to fill missing values (.fillna) with the median value of the House Age column
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      29.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      29.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      29.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      29.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      29.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# Step 4: Explore the data with a scatter plot

plt.figure(figsize=(10, 6)) # Set the size of the figure
plt.scatter(
    housing_df['Longitude'], # x axis
    housing_df['Latitude'], # y axis
    c=housing.target, # Color of points based on median house value
    cmap='plasma', # color map
    alpha=0.5 # transparency
)
plt.colorbar(label='Median House Value ($100,000)')
plt.title('California Housing: Latitude vs. Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
